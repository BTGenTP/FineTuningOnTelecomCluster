# %% [markdown]
# ## PPO / GRPO training (Colab)
#
# Runs GRPO (trainable policy gradient + KL to frozen reference) and PPO (TRL) with the deterministic validator reward.
#
# Assumes `00_colab_setup.ipynb`.
#
# Note: PPO depends on TRL PPO APIs; GRPO uses the lightweight script `scripts/grpo_train.py`.

# %%
from pathlib import Path
import sys

BENCHMARK_ROOT = Path('/content/nav4rails/repositories/FineTuningOnTelecomCluster/benchmark').resolve()
if str(BENCHMARK_ROOT) not in sys.path:
    sys.path.insert(0, str(BENCHMARK_ROOT))

SCRIPTS_DIR = BENCHMARK_ROOT / 'scripts'
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

print('Benchmark root:', BENCHMARK_ROOT)

# %%
# GRPO (trainable) — quick sanity run
# NOTE: will download model weights.

# !python3 scripts/grpo_train.py --config configs/grpo.yaml --n 10 --group-size 2 --epochs 1 --output-root runs/colab_grpo

# %%
# PPO (TRL) — quick sanity run
# NOTE: TRL PPO APIs can vary by version; this script will error if PPO components are unavailable.

# !python3 scripts/ppo_train.py --config configs/ppo.yaml --n 5 --epochs 1 --output-root runs/colab_ppo
