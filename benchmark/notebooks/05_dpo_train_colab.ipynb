# %% [markdown]
# ## DPO training (Colab)
#
# Builds a preference dataset from (chosen, rejected) generations scored by the deterministic validator, then runs TRL DPO.
#
# Assumes `00_colab_setup.ipynb`.

# %%
from pathlib import Path
import sys

BENCHMARK_ROOT = Path('/content/nav4rails/repositories/FineTuningOnTelecomCluster/benchmark').resolve()
if str(BENCHMARK_ROOT) not in sys.path:
    sys.path.insert(0, str(BENCHMARK_ROOT))

SCRIPTS_DIR = BENCHMARK_ROOT / 'scripts'
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))

print('Benchmark root:', BENCHMARK_ROOT)

# %%
# Run DPO via the CLI script (simple, reproducible)
# NOTE: this will download model weights.

# !python3 scripts/dpo_train.py --config configs/dpo.yaml --n 20 --output-root runs/colab_dpo
