# %% [markdown]
# ## NAV4RAIL Benchmark — Colab setup
#
# This notebook bootstraps the `benchmark/` package on Google Colab.
#
# ### 0) Mount drive (optional)
#
# ```python
# from google.colab import drive
#
# drive.mount('/content/drive')
# ```

# %%
# Install dependencies
# !pip -q install -r /content/nav4rails/repositories/FineTuningOnTelecomCluster/benchmark/requirements.txt

# If you're running directly from this repository path, ensure PYTHONPATH points to benchmark/
import sys
from pathlib import Path

BENCHMARK_ROOT = Path('/content/nav4rails/repositories/FineTuningOnTelecomCluster/benchmark').resolve()
if str(BENCHMARK_ROOT) not in sys.path:
    sys.path.insert(0, str(BENCHMARK_ROOT))

print('Benchmark root:', BENCHMARK_ROOT)

# %%
# Allow importing helper scripts like `_fewshot.py` in other notebooks
SCRIPTS_DIR = BENCHMARK_ROOT / 'scripts'
if str(SCRIPTS_DIR) not in sys.path:
    sys.path.insert(0, str(SCRIPTS_DIR))
print('Scripts dir:', SCRIPTS_DIR)
